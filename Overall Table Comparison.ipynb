# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.externals import joblib
# %matplotlib inline

# %% [markdown]
# **This notebook contains the pickled models from Model Offense notebook, and uses them to make predictions on players that the models were not trained on (played less than 5 seasons, or had to skip year 5 due to injury or taking a break, or incoming college players for the 2017 NBA Draft)**

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',10000)

# %%
college = pd.read_csv('/Users/mattlee/GA-Capstone-Project/FEdf1.csv')

# %%
df = pd.read_csv('/Users/mattlee/project-capstone/Clean Data/brdraft.csv')
df['Name'] = df['Name'].apply(lambda x: x.split('\\')[0].lower().title())

# %%
ovrlr = joblib.load('OVR_LR.pkl')
ovrrg = joblib.load('OVR_rg1.pkl')
ovrls = joblib.load('OVR_ls1.pkl')

# %%
def getpredictdfovr(draftdf,featuredf,year,model1,model2,model3):
    tomerge = draftdf[['Year','Pick','Team','Name','College']].copy()
    draftyear = tomerge.loc[tomerge['Year'] == year].copy()
    names = list(draftyear['Name'])
    collegedf = featuredf.loc[featuredf['Name'].isin(names)].copy()
    draftcomp = draftyear.merge(collegedf, on = 'Name')
    x = draftcomp[[u'PPG', u'FGM', u'FG%', u'FTMSR', u'FT%C', u'3PMSR', u'RPG', u'APGCR',
       u'SPGSR', u'TOVSR', u'PF', u'Age at Draft SR', u'Weight at Draft',
       u'Height Inches C', u'TopSchool', u'BPG']]
    predictlr = model1.predict(x)
    predictrg = model2.predict(x)
    predictls = model3.predict(x)
    draftcomp['PredictionsLR'] = predictlr
    draftcomp['PredictionsRG'] = predictrg
    draftcomp['PredictionsLS'] = predictls
    draftcompfinal = draftcomp[['Year_x','Pick','Name','Team_x','College','TotalWS','PredictionsLR','PredictionsRG',
                                'PredictionsLS']].copy()
    draftcompfinal = draftcompfinal.sort_values(by = 'PredictionsRG', ascending = False)
    draftcompfinal = draftcompfinal.reset_index(drop = True)
    draftcompfinal = draftcompfinal.rename_axis('Model Pick')
    draftcompfinal = draftcompfinal.reset_index()
    draftcompfinal['Model Pick'] = draftcompfinal['Model Pick'] + 1
    return draftcompfinal

# %%
d2003 = getpredictdfovr(df,college,2003,ovrlr,ovrrg,ovrls)
d2003
# Out:
#     Model Pick  Year_x  Pick             Name Team_x  \
# 0            1    2003    18       David West    NOH
# 1            2    2003     8        T.J. Ford    MIL
# 2            3    2003     3  Carmelo Anthony    DEN
# 3            4    2003    51      Kyle Korver    NJN
# 4            5    2003     5      Dwyane Wade    MIA
# 5            6    2003     4       Chris Bosh    TOR
# 6            7    2003    13     Marcus Banks    MEM
# 7            8    2003    29      Josh Howard    DAL
# 8            9    2003     6      Chris Kaman    LAC
# 9           10    2003    14     Luke Ridnour    SEA
# 10          11    2003    24       Brian Cook    LAL
# 11          12    2003    38      Steve Blake    WAS
# 12          13    2003    47      Mo Williams    UTA
# 13          14    2003     7     Kirk Hinrich    CHI
# 14          15    2003    10     Jarvis Hayes    WAS
# 15          16    2003    49      James Jones    IND
# 16          17    2003    41     Willie Green    SEA
# ...

# %%
d2004 = getpredictdfovr(df,college,2004,ovrlr,ovrrg,ovrls)
d2004
# Out:
#     Model Pick  Year_x  Pick            Name Team_x  \
# 0            1    2004     5    Devin Harris    WAS
# 1            2    2004     9  Andre Iguodala    PHI
# 2            3    2004    43    Trevor Ariza    NYK
# 3            4    2004    20   Jameer Nelson    DEN
# 4            5    2004    24    Delonte West    BOS
# 5            6    2004     7       Luol Deng    PHO
# 6            7    2004    38     Chris Duhon    CHI
# 7            8    2004    25      Tony Allen    BOS
# 8            9    2004    26    Kevin Martin    SAC
# 9           10    2004    37      Royal Ivey    ATL
# 10          11    2004     3      Ben Gordon    CHI
# 11          12    2004    14  Kris Humphries    UTA
# 12          13    2004     2    Emeka Okafor    CHA
#
#                                  College   TotalWS  PredictionsLR  \
# 0                University of Wisconsin  2.088950       2.121954
# 1                  University of Arizona  2.619775       1.970490
# ...

# %%
d2005 = getpredictdfovr(df,college,2005,ovrlr,ovrrg,ovrls)
d2005
# Out:
#     Model Pick  Year_x  Pick                Name Team_x  \
# 0            1    2005     4          Chris Paul    NOH
# 1            2    2005    17       Danny Granger    IND
# 2            3    2005     1        Andrew Bogut    MIL
# 3            4    2005    38       Travis Diener    ORL
# 4            5    2005     2     Marvin Williams    ATL
# 5            6    2005    30           David Lee    NYK
# 6            7    2005    50          Ryan Gomes    BOS
# 7            8    2005    22        Jarrett Jack    DEN
# 8            9    2005    13            Sean May    CHA
# 9           10    2005    23    Francisco Garcia    SAC
# 10          11    2005     5      Raymond Felton    CHA
# 11          12    2005    33        Brandon Bass    NOH
# 12          13    2005     3      Deron Williams    UTA
# 13          14    2005    21       Nate Robinson    PHO
# 14          15    2005     8       Channing Frye    NYK
# 15          16    2005    19       Hakim Warrick    MEM
# ...

# %%
d2006 = getpredictdfovr(df,college,2006,ovrlr,ovrrg,ovrls)
d2006
# Out:
#     Model Pick  Year_x  Pick               Name Team_x  \
# 0            1    2006    21        Rajon Rondo    PHO
# 1            2    2006    14      Ronnie Brewer    UTA
# 2            3    2006     4       Tyrus Thomas    POR
# 3            4    2006     2  Lamarcus Aldridge    CHI
# 4            5    2006    24         Kyle Lowry    MEM
# 5            6    2006    47       Paul Millsap    UTA
# 6            7    2006    42      Daniel Gibson    CLE
# 7            8    2006    17    Shawne Williams    IND
# 8            9    2006    49          Leon Powe    DEN
# 9           10    2006    36        Craig Smith    MIN
# 10          11    2006    26      Jordan Farmar    LAL
# 11          12    2006    32        Steve Novak    HOU
# 12          13    2006     8           Rudy Gay    HOU
# 13          14    2006    20    Renaldo Balkman    NYK
# 14          15    2006     6        Brandon Roy    MIN
# 15          16    2006     5   Shelden Williams    ATL
# ...

# %%
d2007 = getpredictdfovr(df,college,2007,ovrlr,ovrrg,ovrls)
d2007
# Out:
#     Model Pick  Year_x  Pick             Name Team_x  \
# 0            1    2007     4      Mike Conley    MEM
# 1            2    2007     2     Kevin Durant    SEA
# 2            3    2007    22     Jared Dudley    CHA
# 3            4    2007    37   Josh Mcroberts    POR
# 4            5    2007     3       Al Horford    ATL
# 5            6    2007    15   Rodney Stuckey    DET
# 6            7    2007    35       Glen Davis    SEA
# 7            8    2007     7     Corey Brewer    MIN
# 8            9    2007     9      Joakim Noah    CHI
# 9           10    2007    56   Ramon Sessions    MIL
# 10          11    2007     8   Brandan Wright    CHA
# 11          12    2007    20      Jason Smith    MIA
# 12          13    2007    12   Thaddeus Young    PHI
# 13          14    2007    17    Sean Williams    NJN
# 14          15    2007    10    Spencer Hawes    SAC
# 15          16    2007    47  Dominic Mcguire    WAS
# 16          17    2007    49       Aaron Gray    CHI
# ...

# %%
d2008 = getpredictdfovr(df,college,2008,ovrlr,ovrrg,ovrls)
d2008
# Out:
#     Model Pick  Year_x  Pick                   Name Team_x  \
# 0            1    2008     5             Kevin Love    MEM
# 1            2    2008     2        Michael Beasley    MIA
# 2            3    2008    26            George Hill    SAS
# 3            4    2008    37       Luc Mbah A Moute    MIL
# 4            5    2008    34         Mario Chalmers    MIN
# 5            6    2008     1           Derrick Rose    CHI
# 6            7    2008    11         Jerryd Bayless    IND
# 7            8    2008     9          D.J. Augustin    CHA
# 8            9    2008    19           J.J. Hickson    CLE
# 9           10    2008    21          Ryan Anderson    NJN
# 10          11    2008     4      Russell Westbrook    SEA
# 11          12    2008     7            Eric Gordon    LAC
# 12          13    2008    12         Jason Thompson    SAC
# 13          14    2008    14       Anthony Randolph    GSW
# 14          15    2008    17            Roy Hibbert    TOR
# ...

# %%
d2009 = getpredictdfovr(df,college,2009,ovrlr,ovrrg,ovrls)
d2009
# Out:
#     Model Pick  Year_x  Pick              Name Team_x  \
# 0            1    2009     3      James Harden    OKC
# 1            2    2009    37      Dejuan Blair    SAS
# 2            3    2009    17      Jrue Holiday    PHI
# 3            4    2009    18         Ty Lawson    MIN
# 4            5    2009     4      Tyreke Evans    SAC
# 5            6    2009     7     Stephen Curry    GSW
# 6            7    2009    13  Tyler Hansbrough    IND
# 7            8    2009    44    Chase Budinger    DET
# 8            9    2009    20       Eric Maynor    UTA
# 9           10    2009    21   Darren Collison    NOH
# 10          11    2009    27   Demarre Carroll    MEM
# 11          12    2009    19       Jeff Teague    ATL
# 12          13    2009     9     Demar Derozan    TOR
# 13          14    2009    33  Dante Cunningham    POR
# 14          15    2009    16     James Johnson    CHI
# 15          16    2009    14        Earl Clark    PHO
# ...

# %%
d2010 = getpredictdfovr(df,college,2010,ovrlr,ovrrg,ovrls)
d2010
# Out:
#     Model Pick  Year_x  Pick               Name Team_x  \
# 0            1    2010     7        Greg Monroe    DET
# 1            2    2010     5   Demarcus Cousins    SAC
# 2            3    2010     9     Gordon Hayward    UTA
# 3            4    2010    10        Paul George    IND
# 4            5    2010     1          John Wall    WAS
# 5            6    2010     2        Evan Turner    PHI
# 6            7    2010     3     Derrick Favors    NJN
# 7            8    2010     8    Al-Farouq Aminu    LAC
# 8            9    2010    16       Luke Babbitt    MIN
# 9           10    2010    14  Patrick Patterson    HOU
# 10          11    2010    12       Xavier Henry    MEM
# 11          12    2010     4     Wesley Johnson    MIN
# 12          13    2010    11       Cole Aldrich    NOH
# 13          14    2010    40   Lance Stephenson    IND
# 14          15    2010    23      Trevor Booker    MIN
# 15          16    2010    28    Greivis Vasquez    MEM
# ...

# %%
d2011 = getpredictdfovr(df,college,2011,ovrlr,ovrrg,ovrls)
d2011.sort_values(by = 'TotalWS', ascending = False)
# Out:
#     Model Pick  Year_x  Pick              Name Team_x  \
# 1            2    2011    15     Kawhi Leonard    IND
# 0            1    2011     1      Kyrie Irving    CLE
# 2            3    2011    30      Jimmy Butler    CHI
# 24          25    2011    60     Isaiah Thomas    SAC
# 3            4    2011    22    Kenneth Faried    DEN
# 7            8    2011     9      Kemba Walker    CHA
# 11          12    2011    38  Chandler Parsons    HOU
# 20          21    2011    11     Klay Thompson    GSW
# 9           10    2011    16    Nikola Vucevic    PHI
# 8            9    2011     4  Tristan Thompson    CLE
# 18          19    2011    24    Reggie Jackson    OKC
# 10          11    2011    19     Tobias Harris    CHA
# 19          20    2011    13   Markieff Morris    PHO
# 16          17    2011     8    Brandon Knight    DET
# 12          13    2011    29       Cory Joseph    SAS
# 13          14    2011    50       Lavoy Allen    PHI
# ...

# %%
d2012 = getpredictdfovr(df,college,2012,ovrlr,ovrrg,ovrls)
d2012
# Out:
#     Model Pick  Year_x  Pick                    Name Team_x  \
# 0            1    2012     1           Anthony Davis    NOH
# 1            2    2012     2  Michael Kidd-Gilchrist    CHA
# 2            3    2012    21         Jared Sullinger    BOS
# 3            4    2012     3            Bradley Beal    WAS
# 4            5    2012    34             Jae Crowder    CLE
# 5            6    2012    35          Draymond Green    GSW
# 6            7    2012    18          Terrence Jones    HOU
# 7            8    2012    15        Maurice Harkless    PHI
# 8            9    2012     6          Damian Lillard    POR
# 9           10    2012     4            Dion Waiters    CLE
# 10          11    2012    40             Will Barton    POR
# 11          12    2012    39         Khris Middleton    DET
# 12          13    2012     9          Andre Drummond    DET
# 13          14    2012    12             Jeremy Lamb    HOU
# 14          15    2012     5         Thomas Robinson    SAC
# ...

# %% [markdown]
# **Now we need to input new data to the model and see our predictions**

# %%
def getpredictnewovr(draftdf,featuredf,year,model1,model2,model3):
    tomerge = draftdf[['Year','Pick','Team','Name','College']].copy()
    draftyear = tomerge.loc[tomerge['Year'] == year].copy()
    names = list(draftyear['Name'])
    collegedf = featuredf.loc[featuredf['Name'].isin(names)].copy()
    draftcomp = draftyear.merge(collegedf, on = 'Name')
    x = draftcomp[[u'PPG', u'FGM', u'FG%', u'FTMSR', u'FT%C', u'3PMSR', u'RPG', u'APGCR',
       u'SPGSR', u'TOVSR', u'PF', u'Age at Draft SR', u'Weight at Draft',
       u'Height Inches C', u'TopSchool', u'BPG']]
    predictlr = model1.predict(x)
    predictrg = model2.predict(x)
    predictls = model3.predict(x)
    draftcomp['PredictionsLR'] = predictlr
    draftcomp['PredictionsRG'] = predictrg
    draftcomp['PredictionsLS'] = predictls
    draftcompfinal = draftcomp[['Year_x','Pick','Name','Team_x','PredictionsLR','PredictionsRG',
                                'PredictionsLS']].copy()
    draftcompfinal = draftcompfinal.sort_values(by = 'PredictionsRG', ascending = False)
    draftcompfinal = draftcompfinal.reset_index(drop = True)
    draftcompfinal = draftcompfinal.rename_axis('Model Pick')
    draftcompfinal = draftcompfinal.reset_index()
    draftcompfinal['Model Pick'] = draftcompfinal['Model Pick'] + 1
    return draftcompfinal

# %%
newplayer = pd.read_csv('/Users/mattlee/GA-Capstone-Project/newplayers.csv')

# %%
d2013 = getpredictnewovr(df,newplayer,2013,ovrlr,ovrrg,ovrls)
d2013
# Out:
#     Model Pick  Year_x  Pick                      Name Team_x  PredictionsLR  \
# 0            1    2013     6              Nerlens Noel    NOH       3.350253
# 1            2    2013     3               Otto Porter    WAS       3.296357
# 2            3    2013     4               Cody Zeller    CHA       3.165119
# 3            4    2013    11   Michael Carter-Williams    PHI       3.006457
# 4            5    2013    36              Ray Mccallum    SAC       3.010278
# 5            6    2013     8  Kentavious Caldwell-Pope    DET       2.944731
# 6            7    2013    52             Lorenzo Brown    MIN       2.910353
# 7            8    2013    21              Gorgui Dieng    UTA       2.947520
# 8            9    2013    10             C.J. Mccollum    POR       2.913565
# 9           10    2013    22             Mason Plumlee    BRK       2.875269
# 10          11    2013     2            Victor Oladipo    ORL       2.871725
# ...

# %%
d2014 = getpredictnewovr(df,newplayer,2014,ovrlr,ovrrg,ovrls)
d2014
# Out:
#     Model Pick  Year_x  Pick              Name Team_x  PredictionsLR  \
# 0            1    2014    30     Kyle Anderson    SAS       3.418196
# 1            2    2014     6      Marcus Smart    BOS       3.353363
# 2            3    2014    18       Tyler Ennis    PHO       3.263149
# 3            4    2014    22      Jordan Adams    MEM       3.238085
# 4            5    2014     3       Joel Embiid    PHI       3.102121
# 5            6    2014    24    Shabazz Napier    CHH       2.982978
# 6            7    2014     7     Julius Randle    LAL       2.903000
# 7            8    2014     4      Aaron Gordon    ORL       2.897083
# 8            9    2014    59     Xavier Thames    TOR       2.721461
# 9           10    2014    39      Jerami Grant    PHI       2.698197
# 10          11    2014    19       Gary Harris    CHI       2.720959
# 11          12    2014     1    Andrew Wiggins    CLE       2.672674
# 12          13    2014    42      Nick Johnson    HOU       2.671553
# ...

# %%
d2015 = getpredictnewovr(df,newplayer,2015,ovrlr,ovrrg,ovrls)
d2015
# Out:
#     Model Pick  Year_x  Pick                     Name Team_x  PredictionsLR  \
# 0            1    2015    20             Delon Wright    TOR       3.575579
# 1            2    2015    30             Kevon Looney    GSW       3.179590
# 2            3    2015    24               Tyus Jones    CLE       3.155045
# 3            4    2015    49              Aaron White    WAS       3.036438
# 4            5    2015     6      Willie Cauley-Stein    SAC       3.021838
# 5            6    2015    23  Rondae Hollis-Jefferson    POR       2.947028
# 6            7    2015     1       Karl-Anthony Towns    MIN       2.949730
# 7            8    2015    10          Justise Winslow    MIA       2.938376
# 8            9    2015     8          Stanley Johnson    DET       2.855270
# 9           10    2015    56           Branden Dawson    NOP       2.808091
# 10          11    2015    29         Chris Mccullough    BRK       2.752146
# ...

# %%
d2016 = getpredictnewovr(df,newplayer,2016,ovrlr,ovrrg,ovrls)
d2016
# Out:
#     Model Pick  Year_x  Pick                Name Team_x  PredictionsLR  \
# 0            1    2016     1         Ben Simmons    PHI       3.786775
# 1            2    2016    56     Daniel Hamilton    DEN       2.982894
# 2            3    2016    34          Tyler Ulis    PHO       3.010358
# 3            4    2016     5           Kris Dunn    MIN       2.945412
# 4            5    2016    38       Patrick Mccaw    MIL       2.955663
# 5            6    2016     9        Jakob Poeltl    TOR       2.997130
# 6            7    2016    14    Denzel Valentine    CHI       2.927098
# 7            8    2016    49     Michael Gbinije    DET       2.881747
# 8            9    2016    18      Henry Ellenson    DET       2.825656
# 9           10    2016    52       Joel Bolomboy    UTA       2.792877
# 10          11    2016    36     Malcolm Brogdon    MIL       2.752770
# 11          12    2016    37      Chinanu Onuaku    HOU       2.812150
# ...

# %% [markdown]
# **We will get predictions for the 2017 NBA Draft**

# %%
earlyentry = pd.read_csv('/Users/mattlee/GA-Capstone-Project/earlyentrydf1.csv')

# %%
def getpredictearlyovr(df,model1,model2,model3):
    earlydf = df
    x = df[[u'PPG', u'FGM', u'FG%', u'FTMSR', u'FT%C', u'3PMSR', u'RPG', u'APGCR',
       u'SPGSR', u'TOVSR', u'PF', u'Age at Draft SR', u'Weight at Draft',
       u'Height Inches C', u'TopSchool', u'BPG']]
    predictlr = model1.predict(x)
    predictrg = model2.predict(x)
    predictls = model3.predict(x)
    earlydf['PredictionsLR'] = predictlr
    earlydf['PredictionsRG'] = predictrg
    earlydf['PredictionsLS'] = predictls
    earlydf = earlydf.sort_values(by = 'PredictionsRG', ascending = False)
    earlydf = earlydf.reset_index(drop = True)
    earlydf = earlydf.rename_axis('Model Pick')
    earlydf = earlydf.reset_index()
    earlydf['Model Pick'] = earlydf['Model Pick'] + 1
    return earlydf[['Model Pick','Name','Team','PredictionsLR','PredictionsRG','PredictionsLS']]

# %%
d2017 = getpredictearlyovr(earlyentry,ovrlr,ovrrg,ovrls)
d2017
# Out:
#     Model Pick                 Name    Team  PredictionsLR  PredictionsRG  \
# 0            1           Lonzo Ball    UCLA       3.522445       3.397936
# 1            2  Nigel Williams-Goss      GU       3.236383       3.199645
# 2            3          Tyler Lydon      SU       3.023141       2.988966
# 3            4         Dennis Smith    NCST       3.002844       2.978863
# 4            5       Jonathan Isaac     FSU       3.011498       2.969870
# 5            6         De'Aaron Fox      UK       2.928345       2.935485
# 6            7        Alize Johnson     MSU       2.960759       2.931956
# 7            8          Jawun Evans     OSU       2.912080       2.904007
# 8            9            Ivan Rabb     Cal       2.930605       2.901922
# 9           10         Josh Jackson      KU       2.915572       2.878590
# 10          11         Jayson Tatum    DUKE       2.826655       2.834493
# 11          12      Lauri Markkanen  U of A       2.853445       2.814047
# ...
